# %% [markdown]
# # Analyse multivariée qui a pour but de démontrer les profils types des militant.es

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import scipy.stats as stats


import pprint
import csv
import sys

import sqlite3 as sql

import time
import datetime
from dateutil import parser

from importlib import reload
from shutil import copyfile


from fanalysis.ca import CA 
from fanalysis.mca import MCA
# Importation du fichier csv qui se trouve dans le même dossier que le notebook
data1 = pd.read_csv("CSV/analyse_personnes_occupation.csv")

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6145 entries, 0 to 6144
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   fk_personne      6145 non-null   object
#  1   personne         6145 non-null   object
#  2   gender           6145 non-null   object
#  3   zone_geo         6145 non-null   object
#  4   annee_naissance  6145 non-null   int64
#  5   domaines         6145 non-null   object
#  6   eff              6145 non-null   int64
# dtypes: int64(2), object(5)
# memory usage: 336.2+ KB

# %%
data_cop = data1[data1['annee_naissance'] < 2000].copy(deep=True)
data_cop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6145 entries, 0 to 6144
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   fk_personne      6145 non-null   object
#  1   personne         6145 non-null   object
#  2   gender           6145 non-null   object
#  3   zone_geo         6145 non-null   object
#  4   annee_naissance  6145 non-null   int64
#  5   domaines         6145 non-null   object
#  6   eff              6145 non-null   int64
# dtypes: int64(2), object(5)
# memory usage: 336.2+ KB

# %%
### passer la dataFrame en liste

l = data_cop.values.tolist()

# %%
# domaine de militantisme
a = ['acti_climat', 'acti_LGBT', 'acti_femmes', 'acti_humains']

# occupation principale. c'est à dire métier
b = ['enseignement', 'ecrivain_ne','SHS','sciences_experimentales','sante', 'droit']

# autres occupations
c = ['cinema_TV', 'religieux_ses', 'artiste', 'feministe',  'politique', 'autre']

# %%
def coder(l, a, b, c):
    
    ll = []

    ## si il n'y a pas d'autres disciplines
    # complète avec disciplines principales additionnelles
   
    d= b + c
    for e in l:

        e = list(e)
        
        o1 = ''
        for el in a:
            # dès que la variable o1 est remplie sort de la boucle
            if el in e[5] and len(o1) == 0:
                o1 = el
                e.append('d1_'+ el)   
        if not(len(o1) > 0):
            e.append('d1_nr')

        o2 = ''
        for el in d:
            if el in e[5] and len(o2) == 0:
                o2 = el
                e.append('d2_'+ o2)
        if not(len(o2) > 0):
            e.append('d2_nr')


        o3 = ''
        for el in b:
            if el in e[5] and len(o3) == 0\
                    and el != o1:
                o3 = el
                e.append('d3_'+ o3)
        if not(len(o3) > 0):
            e.append('d3_nr')

        o4 = ''
        for el in d:
            if len(o4) == 0 and el in e[5]\
                    and el != o3 and el != o1:
                o4 = el
                e.append('d4_'+ o4)
        if not(len(o4) > 0):
            e.append('d4_nr')


        ll.append(e)

    return ll

# %%
ll = coder(l, a, b, c)

# %%
df_ll = pd.DataFrame(ll, columns=['uri', 'nom', 'genre', 'origine_geo', 'annee_nais',
                      'liste_occup', 'eff_occupations', 'o1', 'o2', 'o3', 'o4'])
df_ll.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6145 entries, 0 to 6144
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   uri              6145 non-null   object
#  1   nom              6145 non-null   object
#  2   genre            6145 non-null   object
#  3   origine_geo      6145 non-null   object
#  4   annee_nais       6145 non-null   int64
#  5   liste_occup      6145 non-null   object
#  6   eff_occupations  6145 non-null   int64
#  7   o1               6145 non-null   object
#  8   o2               6145 non-null   object
#  9   o3               6145 non-null   object
#  10  o4               6145 non-null   object
# dtypes: int64(2), object(9)
# memory usage: 528.2+ KB

# %%
df_ll.groupby(by='o1').size().sort_values(ascending=False)
# Out:
# o1
# d1_acti_humains    2517
# d1_acti_femmes     2295
# d1_acti_LGBT       1106
# d1_acti_climat      227
# dtype: int64

# %%
df_ll.groupby(by='o4').size().sort_values(ascending=False)
# Out:
# o4
# d4_nr                         2646
# d4_politique                  1179
# d4_autre                       397
# d4_cinema_TV                   392
# d4_SHS                         365
# d4_ecrivain_ne                 334
# d4_artiste                     280
# d4_feministe                   179
# d4_droit                       123
# d4_sciences_experimentales      91
# d4_religieux_ses                81
# d4_sante                        78
# dtype: int64

# %% [markdown]
# ## Commentaire
# l'occupation 4 sera abandonnée comme elle n'est pas renseignée pour plus de la moitié de la population

# %%
### Année minimale et maximale dans la population
min(df_ll['annee_nais']), max(df_ll['annee_nais'])
# Out:
# (1816, 1999)

# %%
l_25 = list(range(1816, 2017, 25))
l_25 [:5], l_25[-5:]
# Out:
# ([1816, 1841, 1866, 1891, 1916], [1916, 1941, 1966, 1991, 2016])

# %%
# On ajoute une nouvelle colonne qui contient la période sur la base de la liste précédente
# et de la valeur de l'année

df_ll['periodes'] = pd.cut(df_ll['annee_nais'], l_25, right=False)

### Transformer le code ajouté pour qu'il soit plus lisible
# noter qu'on a arrondi les valeurs
df_ll['periodes'] = df_ll['periodes'].apply(lambda x : str(int(x.left))+'-'+ str(int(x.right)-1))

# Inspection
df_ll.head(3)
# Out:
#                                       uri                     nom genre  \
# 0  http://www.wikidata.org/entity/Q231690  Bhimrao Ramji Ambedkar     M
# 1   http://www.wikidata.org/entity/Q19526            Maya Angelou     F
# 2  http://www.wikidata.org/entity/Q318509           Henry Rollins     M
#
#         origine_geo  annee_nais  \
# 0             Asie         1891
# 1  Amérique du nord        1928
# 2  Amérique du nord        1961
#
#                                          liste_occup  eff_occupations  \
# 0  ecrivain_ne,politique,enseignement,droit,SHS,S...               68
# 1  cinema_TV,ecrivain_ne,politique,enseignement,a...               19
# 2  cinema_TV,cinema_TV,ecrivain_ne,ecrivain_ne,ar...               18
#
#                 o1               o2               o3              o4  \
# 0   d1_acti_femmes  d2_enseignement  d3_enseignement  d4_ecrivain_ne
# 1  d1_acti_humains  d2_enseignement  d3_enseignement  d4_ecrivain_ne
# 2  d1_acti_humains   d2_ecrivain_ne   d3_ecrivain_ne    d4_cinema_TV
#
#     periodes
# 0  1891-1915
# 1  1916-1940
# 2  1941-1965

# %%
### compter les naissances par périodes de 25 ans
ax = df_ll.groupby(by='periodes', observed=True).size().plot(kind='bar',rot=60, fontsize=8, figsize=(16,8))
ax.bar_label(ax.containers[0], fontsize=12)

plt.ylabel('Effectif')
plt.xlabel('Périodes')
plt.title('Naissances par périodes de 25 ans')
plt.show()

# %% [markdown]
# ## Profil type pour toute la population
# Pour garder de la cohérence nous allons analyser que les personnes qui ont vécu lors du XXe siècle

# %%
### On notera l'effectif trop important des individus pour lesquels cette variable
# n'est pas renseignée. Mieux vaudra ne pas l'utiliser
df_d2 = df_ll[df_ll.annee_nais > 1800].groupby(by='o2').size().sort_values(ascending=False)
df_d2
# Out:
# o2
# d2_ecrivain_ne                1710
# d2_nr                         1365
# d2_enseignement                804
# d2_politique                   648
# d2_droit                       378
# d2_SHS                         262
# d2_autre                       226
# d2_cinema_TV                   203
# d2_artiste                     174
# d2_sante                       133
# d2_sciences_experimentales     121
# d2_feministe                    66
# d2_religieux_ses                55
# dtype: int64

# %%
# Exclure les modalités les moins fréquentes
l_d2 = df_d2.index.to_list()[:-2]
print(l_d2)
# Out:
# ['d2_ecrivain_ne', 'd2_nr', 'd2_enseignement', 'd2_politique', 'd2_droit', 'd2_SHS', 'd2_autre', 'd2_cinema_TV', 'd2_artiste', 'd2_sante', 'd2_sciences_experimentales']

# %%
df_d3 = df_ll[df_ll.annee_nais > 1800].groupby(by='o3').size().sort_values(ascending=False)
df_d3
# Out:
# o3
# d3_nr                         2737
# d3_ecrivain_ne                1710
# d3_enseignement                804
# d3_droit                       378
# d3_SHS                         262
# d3_sante                       133
# d3_sciences_experimentales     121
# dtype: int64

# %%
## j'enlève la santé et quand c'est pas renseigné.
l_d3 = df_d3.index.to_list()[1:]
print(l_d3)
# Out:
# ['d3_ecrivain_ne', 'd3_enseignement', 'd3_droit', 'd3_SHS', 'd3_sante', 'd3_sciences_experimentales']

# %%
df_d4 = df_ll[df_ll.annee_nais > 1800].groupby(by='o4').size().sort_values(ascending=False)
df_d4
# Out:
# o4
# d4_nr                         2646
# d4_politique                  1179
# d4_autre                       397
# d4_cinema_TV                   392
# d4_SHS                         365
# d4_ecrivain_ne                 334
# d4_artiste                     280
# d4_feministe                   179
# d4_droit                       123
# d4_sciences_experimentales      91
# d4_religieux_ses                81
# d4_sante                        78
# dtype: int64

# %%
df_ll[df_ll.annee_nais > 1800].groupby(by='periodes', observed=True).size().sort_values(ascending=False)
# Out:
# periodes
# 1941-1965    1892
# 1966-1990    1599
# 1916-1940     961
# 1866-1890     492
# 1891-1915     425
# 1841-1865     382
# 1991-2015     256
# 1816-1840     138
# dtype: int64

# %%
cdf_og = df_ll[df_ll.annee_nais > 1800].groupby(by='origine_geo', observed=True).size().sort_values(ascending=False)
cdf_og
# Out:
# origine_geo
# Europe              2628
# Amérique du nord    1093
# Asie                1000
# Amérique du sud      751
# Afrique              510
# Océanie              163
# dtype: int64

# %%
l_og = cdf_og.index.to_list()[:-1]
print(l_og)
# Out:
# ['Europe', 'Amérique du nord', 'Asie ', 'Amérique du sud', 'Afrique']

# %% [markdown]
# ## Préparer le tableau à analyser
#
# Il est nécessaire de recoder le tableau pour ne pas avoir des variables avec modalités vides: on utilise donc un nouveau tableau avec les individus nés après 1890.
#
# Aussi, si on n'enlève pas les modalités les moins fréquentes (cf. distributions ci-dessus) elles impactent massivement l'analyse factorielle des correspondances multiples, car les modalités les moins fréquentes apportent le plus de variation. On doit donc inspecter manuellement les profils rares mais les exclure de l'ACM pour mettre en évidence des structures plus importantes.

# %%
### Créer une copie indépendante du DataFrame 
# tout en éliminant les modalités peu fréquentes 
cdf_mod = df_ll[(df_ll['annee_nais'] > 1800)\
                & (df_ll.origine_geo.isin(l_og))\
                & (df_ll.o2.isin(l_d2))\
                & (df_ll.o3.isin(l_d3))]\
                    .copy(deep=True).reset_index(names='orig_index')
print(len(cdf_mod))
cdf_mod.head(3)
# Out:
# 3320
#    orig_index                                     uri                     nom  \
# 0           0  http://www.wikidata.org/entity/Q231690  Bhimrao Ramji Ambedkar
# 1           1   http://www.wikidata.org/entity/Q19526            Maya Angelou
# 2           2  http://www.wikidata.org/entity/Q318509           Henry Rollins
#
#   genre       origine_geo  annee_nais  \
# 0     M             Asie         1891
# 1     F  Amérique du nord        1928
# 2     M  Amérique du nord        1961
#
#                                          liste_occup  eff_occupations  \
# 0  ecrivain_ne,politique,enseignement,droit,SHS,S...               68
# 1  cinema_TV,ecrivain_ne,politique,enseignement,a...               19
# 2  cinema_TV,cinema_TV,ecrivain_ne,ecrivain_ne,ar...               18
#
#                 o1               o2               o3              o4  \
# 0   d1_acti_femmes  d2_enseignement  d3_enseignement  d4_ecrivain_ne
# 1  d1_acti_humains  d2_enseignement  d3_enseignement  d4_ecrivain_ne
# 2  d1_acti_humains   d2_ecrivain_ne   d3_ecrivain_ne    d4_cinema_TV
#
#     periodes
# 0  1891-1915
# 1  1916-1940
# 2  1941-1965

# %%
## max d'individus
max(cdf_mod.index)
# Out:
# 3319

# %%
### Année minimale et maximale dans la population
min(cdf_mod['annee_nais']), max(cdf_mod['annee_nais'])
# Out:
# (1817, 1999)

# %%
DActives = cdf_mod[['periodes', 'origine_geo',
 'o1', 'o2', 'o3']].copy(deep=True)

# %%
DActives.groupby(by='periodes', observed=False).size()
# Out:
# periodes
# 1816-1840      96
# 1841-1865     262
# 1866-1890     317
# 1891-1915     228
# 1916-1940     539
# 1941-1965    1020
# 1966-1990     767
# 1991-2015      91
# dtype: int64

# %%
### Structure du tableau à analyser
# nombre de variables
p = DActives.shape[1]
# nombre d'observations
n = DActives.shape[0]
print('Nombre variables:', p, 'Nombre lignes:', n)
# codage en 0/1
X = pd.get_dummies(DActives,prefix='',prefix_sep='')*1
# Out:
# Nombre variables: 5 Nombre lignes: 3320

# %% [markdown]
# ### Distance des individus par rapport au profil moyen

# %%
#Calcul du profil de l'individu moyen
ind_moy = np.sum(X.values,axis=0)/(n*p)
print(ind_moy)
# Out:
# [0.00578313 0.01578313 0.01909639 0.01373494 0.03246988 0.06144578
#  0.04620482 0.00548193 0.01487952 0.03650602 0.02174699 0.02843373
#  0.09843373 0.02831325 0.00686747 0.08710843 0.07771084 0.01536145
#  0.02222892 0.10066265 0.04674699 0.00795181 0.00704819 0.01536145
#  0.02222892 0.10066265 0.04674699 0.00795181 0.00704819]

# %%
### Ajouter une colonne avec la distance chi-2 de chaque individu par rapport à l'individu moyen
# pour chaque individu: les individus plus éloignés sont plus rares
X['dist_org'] = X.apply(lambda x: round(np.sum(1/ind_moy*(x/p-ind_moy)**2),4), raw=True, axis=1)

# %%
### Inspecter le tableau
X.sort_values(by='dist_org', ascending=False).head(10)['dist_org']
# Out:
# 2054    26.1600
# 1488    26.1600
# 2459    23.8781
# 586     20.7946
# 2600    20.7946
# 2378    20.0174
# 824     20.0174
# 1756    19.7290
# 2449    19.6094
# 2373    19.5048
# Name: dist_org, dtype: float64

# %%
### Distribution de la distance chi-2

sns.set_theme(style="whitegrid",rc={"figure.figsize":(10,2)} )


a = X['dist_org']
# a = X['dist_org'][X['dist_org']< 20]

print(a.describe())

ax = sns.violinplot(x=a)

### Noter que au delà des limites les valeurs sont coupées car postulées
ax.set_xlim(left=min(a), right=max(a))

plt.show()
# Out:
# count    3320.000000
# mean        4.799997
# std         3.289355
# min         1.311300
# 25%         2.582000
# 50%         3.671500
# 75%         5.818700
# max        26.160000
# Name: dist_org, dtype: float64

# %%
### Ajouter la distance des individus à leur données
# On créé un nouveau DataFrame qui résulte de la jointure des deux précédents
cdf_mod_dist= pd.merge(cdf_mod, X.dist_org, left_index=True, right_index=True)
cdf_mod_dist[:3]
# Out:
#    orig_index                                     uri                     nom  \
# 0           0  http://www.wikidata.org/entity/Q231690  Bhimrao Ramji Ambedkar
# 1           1   http://www.wikidata.org/entity/Q19526            Maya Angelou
# 2           2  http://www.wikidata.org/entity/Q318509           Henry Rollins
#
#   genre       origine_geo  annee_nais  \
# 0     M             Asie         1891
# 1     F  Amérique du nord        1928
# 2     M  Amérique du nord        1961
#
#                                          liste_occup  eff_occupations  \
# 0  ecrivain_ne,politique,enseignement,droit,SHS,S...               68
# 1  cinema_TV,ecrivain_ne,politique,enseignement,a...               19
# 2  cinema_TV,cinema_TV,ecrivain_ne,ecrivain_ne,ar...               18
#
#                 o1               o2               o3              o4  \
# 0   d1_acti_femmes  d2_enseignement  d3_enseignement  d4_ecrivain_ne
# 1  d1_acti_humains  d2_enseignement  d3_enseignement  d4_ecrivain_ne
# 2  d1_acti_humains   d2_ecrivain_ne   d3_ecrivain_ne    d4_cinema_TV
#
#     periodes  dist_org
# 0  1891-1915    5.4896
# 1  1916-1940    3.5537
# 2  1941-1965    2.0562

# %%
## Individus proches du profil moyen
#  donc fréquents
df_filtered = cdf_mod_dist[cdf_mod_dist.dist_org<2]
print(len(df_filtered))
df_filtered.sort_values(by='dist_org')[:5]
# Out:
# 349
#       orig_index                                        uri  \
# 7              7  http://www.wikidata.org/entity/Q104530956
# 637          773     http://www.wikidata.org/entity/Q465183
# 1485        1846     http://www.wikidata.org/entity/Q106748
# 1527        1908   http://www.wikidata.org/entity/Q96101676
# 616          750    http://www.wikidata.org/entity/Q4989925
#
#                      nom genre origine_geo  annee_nais  \
# 7            Vesna Kesić     F      Europe        1948
# 637    Renate Dorrestein     F      Europe        1954
# 1485         Seyran Ateş     F      Europe        1963
# 1527  Brigette Boucheron     F      Europe        1947
# 616               Trille     F      Europe        1945
#
#                                             liste_occup  eff_occupations  \
# 7     cinema_TV,cinema_TV,cinema_TV,cinema_TV,SHS,SH...               16
# 637   cinema_TV,ecrivain_ne,ecrivain_ne,ecrivain_ne,...                5
# 1485        ecrivain_ne,droit,religieux_ses,acti_femmes                4
# 1527                      ecrivain_ne,acti_femmes,autre                3
# 616     artiste,artiste,ecrivain_ne,artiste,acti_femmes                5
#
#                   o1              o2              o3            o4   periodes  \
# 7     d1_acti_femmes  d2_ecrivain_ne  d3_ecrivain_ne        d4_SHS  1941-1965
# 637   d1_acti_femmes  d2_ecrivain_ne  d3_ecrivain_ne  d4_cinema_TV  1941-1965
# 1485  d1_acti_femmes  d2_ecrivain_ne  d3_ecrivain_ne      d4_droit  1941-1965
# 1527  d1_acti_femmes  d2_ecrivain_ne  d3_ecrivain_ne      d4_autre  1941-1965
# 616   d1_acti_femmes  d2_ecrivain_ne  d3_ecrivain_ne    d4_artiste  1941-1965
#
#       dist_org
# 7       1.3113
# 637     1.3113
# 1485    1.3113
# 1527    1.3113
# 616     1.3113

# %%
## Inspecter les combinaisons les plus fréquentes
cdf_mod_dist.groupby(by=['periodes','origine_geo','o1','o2','o3'],\
                       observed=True).size().sort_values(ascending=False).head(10)
# Out:
# periodes   origine_geo  o1               o2               o3
# 1866-1890  Europe       d1_acti_femmes   d2_ecrivain_ne   d3_ecrivain_ne     119
# 1841-1865  Europe       d1_acti_femmes   d2_ecrivain_ne   d3_ecrivain_ne     114
# 1966-1990  Asie         d1_acti_humains  d2_ecrivain_ne   d3_ecrivain_ne      81
# 1941-1965  Europe       d1_acti_humains  d2_ecrivain_ne   d3_ecrivain_ne      80
#                         d1_acti_LGBT     d2_ecrivain_ne   d3_ecrivain_ne      76
# 1841-1865  Europe       d1_acti_femmes   d2_enseignement  d3_enseignement     71
# 1966-1990  Europe       d1_acti_humains  d2_ecrivain_ne   d3_ecrivain_ne      63
# 1916-1940  Europe       d1_acti_humains  d2_ecrivain_ne   d3_ecrivain_ne      62
# 1941-1965  Europe       d1_acti_femmes   d2_ecrivain_ne   d3_ecrivain_ne      57
# 1866-1890  Europe       d1_acti_femmes   d2_enseignement  d3_enseignement     57
# dtype: int64

# %% [markdown]
# ## Commentaire
# Il y a une majorité de personne qui ont comme occupation écrivain.ne et qui viennent d'Europe

# %%
### Individus moyennements distants du profil moyen
df_filtered = cdf_mod_dist[(cdf_mod_dist.dist_org>4.5) & (cdf_mod_dist.dist_org <5.5)]
print(len(df_filtered))
df_filtered.sort_values(by='dist_org')[:5]
# Out:
# 284
#       orig_index                                       uri  \
# 546          674  http://www.wikidata.org/entity/Q66626452
# 1834        2330  http://www.wikidata.org/entity/Q50407448
# 1386        1715   http://www.wikidata.org/entity/Q1516440
# 146          172   http://www.wikidata.org/entity/Q6745294
# 2823        3917  http://www.wikidata.org/entity/Q44403762
#
#                      nom genre origine_geo  annee_nais  \
# 546   Aisha Musa el-Said     F     Afrique        1950
# 1834      Ilhem Marzouki     F     Afrique        1957
# 1386        Nahid Toubia     F     Afrique        1951
# 146   Mama Koite Doumbia     F     Afrique        1950
# 2823     Monia Ben Jemia     F     Afrique        1958
#
#                                             liste_occup  eff_occupations  \
# 546   ecrivain_ne,politique,ecrivain_ne,enseignement...                5
# 1834                       SHS,enseignement,acti_femmes                3
# 1386               sante,enseignement,sante,acti_femmes                4
# 146   politique,acti_humains,enseignement,acti_femme...                8
# 2823                           enseignement,acti_femmes                2
#
#                   o1               o2               o3              o4  \
# 546   d1_acti_femmes  d2_enseignement  d3_enseignement  d4_ecrivain_ne
# 1834  d1_acti_femmes  d2_enseignement  d3_enseignement          d4_SHS
# 1386  d1_acti_femmes  d2_enseignement  d3_enseignement        d4_sante
# 146   d1_acti_femmes  d2_enseignement  d3_enseignement    d4_politique
# 2823  d1_acti_femmes  d2_enseignement  d3_enseignement           d4_nr
#
#        periodes  dist_org
# 546   1941-1965    4.5098
# 1834  1941-1965    4.5098
# 1386  1941-1965    4.5098
# 146   1941-1965    4.5098
# 2823  1941-1965    4.5098

# %% [markdown]
# ## Individus très distants du profil moyen

# %%
### Individus très distants du profil moyen
#  donc rares, triés en commençant par les plus rares
df_filtered = cdf_mod_dist[cdf_mod_dist.dist_org>15]
print(len(df_filtered))
df_filtered.sort_values(by='dist_org', ascending=False)[:10]
# Out:
# 31
#       orig_index                                        uri  \
# 2054        2607   http://www.wikidata.org/entity/Q27889892
# 1488        1849  http://www.wikidata.org/entity/Q106604621
# 2459        3179  http://www.wikidata.org/entity/Q103825027
# 586          718   http://www.wikidata.org/entity/Q55657627
# 2600        3477   http://www.wikidata.org/entity/Q66237923
# 2378        3063  http://www.wikidata.org/entity/Q115055261
# 824          987  http://www.wikidata.org/entity/Q117330103
# 1756        2227   http://www.wikidata.org/entity/Q57087586
# 2449        3165  http://www.wikidata.org/entity/Q105546379
# 2373        3057  http://www.wikidata.org/entity/Q115650531
#
#                          nom genre      origine_geo  annee_nais  \
# 2054       Shaama Sandooyeea     F          Afrique        1997
# 1488              Kevin Mtai     M          Afrique        1996
# 2459    Katharina Rogenhofer     F           Europe        1994
# 586            Zainab Fasiki     F          Afrique        1994
# 2600                Zara Kay     F          Afrique        1992
# 2378      Mukhtar Abdulsalam     M          Afrique        1993
# 824          Anisa Bek Derna     F          Afrique        1997
# 1756  Hindou Oumarou Ibrahim     F          Afrique        1984
# 2449               Vivi Reis     F  Amérique du sud        1991
# 2373             Gehad Hamdy     F          Afrique        1995
#
#                                             liste_occup  eff_occupations  \
# 2054          sciences_experimentales,autre,acti_climat                3
# 1488  acti_humains,acti_climat,sciences_experimental...                4
# 2459    sciences_experimentales,acti_climat,acti_climat                3
# 586   artiste,artiste,sciences_experimentales,artist...                5
# 2600                sciences_experimentales,acti_femmes                2
# 2378                          politique,SHS,acti_climat                3
# 824           autre,SHS,cinema_TV,politique,acti_climat                5
# 1756   sciences_experimentales,acti_humains,acti_climat                3
# 2449                          politique,sante,acti_LGBT                3
# 2373                            sante,sante,acti_femmes                3
#
#                   o1                          o2                          o3  \
# 2054  d1_acti_climat  d2_sciences_experimentales  d3_sciences_experimentales
# 1488  d1_acti_climat  d2_sciences_experimentales  d3_sciences_experimentales
# 2459  d1_acti_climat  d2_sciences_experimentales  d3_sciences_experimentales
# 586   d1_acti_femmes  d2_sciences_experimentales  d3_sciences_experimentales
# 2600  d1_acti_femmes  d2_sciences_experimentales  d3_sciences_experimentales
# 2378  d1_acti_climat                      d2_SHS                      d3_SHS
# 824   d1_acti_climat                      d2_SHS                      d3_SHS
# 1756  d1_acti_climat  d2_sciences_experimentales  d3_sciences_experimentales
# 2449    d1_acti_LGBT                    d2_sante                    d3_sante
# 2373  d1_acti_femmes                    d2_sante                    d3_sante
#
#                 o4   periodes  dist_org
# 2054      d4_autre  1991-2015   26.1600
# 1488  d4_politique  1991-2015   26.1600
# 2459         d4_nr  1991-2015   23.8781
# 586     d4_artiste  1991-2015   20.7946
# 2600         d4_nr  1991-2015   20.7946
# 2378  d4_politique  1991-2015   20.0174
# 824   d4_cinema_TV  1991-2015   20.0174
# 1756         d4_nr  1966-1990   19.7290
# 2449  d4_politique  1991-2015   19.6094
# 2373         d4_nr  1991-2015   19.5048

# %% [markdown]
# ## Inspection des modalités des variables

# %%
### Profil moyen colonnes
moda_moy = np.ones(X.shape[0])/n
moda_moy[:10]
# Out:
# array([0.0003012, 0.0003012, 0.0003012, 0.0003012, 0.0003012, 0.0003012,
#        0.0003012, 0.0003012, 0.0003012, 0.0003012])

# %%
# enelver la colonne 'dist-org'
df = X.iloc[:,:-1]
# somme en colonne
somme_col = np.sum(df.values,axis=0)
print(somme_col)
# poids des variables_modalités (points modalités)
poids_moda = somme_col/(n*p)
# distance au chi-2 de la valeur moyenne
disto_moda = np.apply_along_axis(arr=df.values/somme_col,axis=0,func1d=lambda x:
np.sum(n*(x-moda_moy)**2))
#np
inertie_moda = poids_moda * disto_moda
#affichage
dfc = pd.DataFrame(np.transpose([poids_moda,disto_moda,inertie_moda]),index=df.columns,columns=['Poids','Disto','Inertie'])


### La disposition des lignes est en fonction des modalités, 
# et la somme des colonnes a été transposée pour avoir des lignes

### Noter que les modalités rares apportent beaucoup de variation
# mais que leur valeur est pondérée en la multipliant par leur (petite) fréquence (=poids)
dfc
# Out:
# [  96  262  317  228  539 1020  767   91  247  606  361  472 1634  470
#   114 1446 1290  255  369 1671  776  132  117  255  369 1671  776  132
#   117]
#                                Poids      Disto   Inertie
# 1816-1840                   0.005783  33.583333  0.194217
# 1841-1865                   0.015783  11.671756  0.184217
# 1866-1890                   0.019096   9.473186  0.180904
# 1891-1915                   0.013735  13.561404  0.186265
# 1916-1940                   0.032470   5.159555  0.167530
# 1941-1965                   0.061446   2.254902  0.138554
# 1966-1990                   0.046205   3.328553  0.153795
# 1991-2015                   0.005482  35.483516  0.194518
# Afrique                     0.014880  12.441296  0.185120
# Amérique du nord            0.036506   4.478548  0.163494
# Amérique du sud             0.021747   8.196676  0.178253
# Asie                        0.028434   6.033898  0.171566
# Europe                      0.098434   1.031824  0.101566
# d1_acti_LGBT                0.028313   6.063830  0.171687
# d1_acti_climat              0.006867  28.122807  0.193133
# d1_acti_femmes              0.087108   1.295989  0.112892
# d1_acti_humains             0.077711   1.573643  0.122289
# d2_SHS                      0.015361  12.019608  0.184639
# d2_droit                    0.022229   7.997290  0.177771
# d2_ecrivain_ne              0.100663   0.986834  0.099337
# d2_enseignement             0.046747   3.278351  0.153253
# d2_sante                    0.007952  24.151515  0.192048
# d2_sciences_experimentales  0.007048  27.376068  0.192952
# d3_SHS                      0.015361  12.019608  0.184639
# d3_droit                    0.022229   7.997290  0.177771
# d3_ecrivain_ne              0.100663   0.986834  0.099337
# d3_enseignement             0.046747   3.278351  0.153253
# d3_sante                    0.007952  24.151515  0.192048
# d3_sciences_experimentales  0.007048  27.376068  0.192952

# %%
### distance au chi-2 de la valeur moyenne
# Les premières modalités sont celles qui sont plus rares
ax = round(dfc.Disto.sort_values(ascending=True),2).plot(kind='barh', 
                    figsize=(6,10))

ax.bar_label(ax.containers[0])

plt.show()

# %%
### Inertie, i.e. contribution à la variance
ax = round(dfc.Inertie.sort_values(ascending=True),2).plot(kind='barh', 
                    figsize=(6,10))

ax.bar_label(ax.containers[0])

plt.show()

# %%
acm = MCA(row_labels=DActives.index,var_labels=DActives.columns)
acm.fit(DActives.values)
# Out:
# MCA(row_labels=RangeIndex(start=0, stop=3320, step=1),
#     var_labels=Index(['periodes', 'origine_geo', 'o1', 'o2', 'o3'], dtype='object'))

# %%
eig = pd.DataFrame(acm.eig_).transpose()
eig.columns=['contribution','freq','freq_cumulee']

eig.head(), eig.tail()
# Out:
# (   contribution       freq  freq_cumulee
#  0      0.480480  10.010001     10.010001
#  1      0.414677   8.639108     18.649110
#  2      0.412095   8.585310     27.234419
#  3      0.404706   8.431370     35.665789
#  4      0.401906   8.373046     44.038835,
#      contribution          freq  freq_cumulee
#  19  8.859778e-31  1.845787e-29         100.0
#  20  3.672547e-31  7.651139e-30         100.0
#  21  2.853467e-31  5.944723e-30         100.0
#  22  1.374023e-31  2.862549e-30         100.0
#  23  1.042338e-31  2.171537e-30         100.0)

# %%
### Nombre total de modalités, toute variable confondue
M = X.shape[1]
print('Nombre de modalités:', M)
#nombre max de facteurs
Hmax = M-p
print('Nombre maximal de facteurs:', Hmax)
# Out:
# Nombre de modalités: 30
# Nombre maximal de facteurs: 25

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(12,3))

eig.iloc[:,0].plot(kind='bar', ax=axes[0], title='Eigenvalue des axes')
eig.iloc[:,1].plot(kind='bar', ax=axes[1], title="Proportion de l'eigenvalue ")
eig.iloc[:,2].plot(kind='bar', ax=axes[2], title="Frequence cumulative de l'eigenvalue ")
# Met les valeurs xticks en vertical
fig.autofmt_xdate(rotation=0)
plt.show()

# %%
#éboulis des v.p.

xvalues = len(acm.eig_[0])+1

fix,ax = plt.subplots(figsize=(5,5))
ax.plot(range(1,xvalues),acm.eig_[0],".-")
ax.set_xlabel("Nb. facteurs")
ax.set_ylabel("Val. propres")
plt.title("Eboulis des valeurs propres")
#seuil - Règle de Kaiser
ax.plot([1,xvalues-1],[1/p,1/p],"r--",linewidth=1)
plt.show()

# %%
### Correction de Benzecri, cf. Rakotomalala, Pratique, p.313sqq

#somme en colonne
#récupérer les valeurs propres supérieur à (1/p)
lambada = acm.eig_[0][acm.eig_[0]>1/p]
#print(lambada)

#appliquer la correction
lambada_prim = ((p/(p-1))*(lambada-1/p))**2
#print(lambada_prim)

#faire la somme
S_prim = np.sum(lambada_prim)
#print('u',S_prim)

#et produire les pourcentages
percent_prim = lambada_prim/S_prim*100

#affichage
bzc = pd.DataFrame(np.transpose(np.array([lambada_prim,percent_prim,
                                np.cumsum(percent_prim)])),columns=['Val.P','freq','Cumul_freq'],
                                index=range(1,len(percent_prim)+1))
print(bzc)
# Out:
#        Val.P       freq  Cumul_freq
# 1   0.122920  30.184743   30.184743
# 2   0.072010  17.682972   47.867715
# 3   0.070288  17.260118   65.127833
# 4   0.065476  16.078426   81.206259
# 5   0.063697  15.641662   96.847921
# 6   0.009556   2.346616   99.194537
# 7   0.002100   0.515710   99.710246
# 8   0.000725   0.178055   99.888301
# 9   0.000348   0.085416   99.973717
# 10  0.000097   0.023840   99.997556
# 11  0.000010   0.002444  100.000000

# %%
### Préparer un calcul dynamique des dimensions du graphique
# print(acm.col_topandas().columns)
max(acm.col_topandas().col_coord_dim1), min(acm.col_topandas().col_coord_dim1)
# Out:
# (2.146065326422046, -1.1315664504834917)

# %%
# Mapping des points colonnes

i = 1
dfc = acm.col_topandas()

df_rows = acm.row_topandas()




### avec la correction de Benzecri, 
# 3 axes apportent 95%  de l'information
while i < 8:    

    c1 = 'col_contrib_dim' + str(i)  
    c2 = 'col_contrib_dim' + str(1+i)

    #c1 = 'col_cos2_dim' + str(i)  
    #c2 = 'col_cos2_dim' + str(1+i)


    
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,3))

    r1 = dfc[c1].sort_values(ascending=True)[:10]
    r1.plot(kind='barh', ax=axes[0], title="Contribution de l'axe"+ str(i))

    r2 = dfc[c2].sort_values(ascending=True)[:10]
    r2.plot(kind='barh', ax=axes[1], title="Contribution de l'axe"+ str(i+1))

    plt.tight_layout()
    plt.show()


    # rc1 = 'row_contrib_dim' + str(i)  
    # rc2 = 'row_contrib_dim' + str(1+i)
    rc1 = 'row_cos2_dim' + str(i)  
    rc2 = 'row_cos2_dim' + str(1+i)

    ### Filtrer les individus donnant la plus grande contribution à l'axe
    # On retient les individus les mieux représentés sur chaque axe
    rcv1 = df_rows[rc1].sort_values(ascending=False)[:8].index
    rcv2 = df_rows[rc2].sort_values(ascending=False)[:8].index

    lrc = list(set(list(rcv1) + list(rcv2)))


    min_d1 = min(dfc['col_coord_dim' + str(i)])-0.2
    max_d1 = max(dfc['col_coord_dim' + str(i)])+0.2
    min_d2 = min(dfc['col_coord_dim' + str(i+1)])-0.2
    max_d2 = max(dfc['col_coord_dim' + str(i+1)])+0.2

    #représentation simultanée
    #fig,ax = plt.subplots(figsize=(20, 20)
    fig,ax = plt.subplots(figsize=((min_d1*-1 + max_d1)*4, (min_d2*-1 + max_d2)*4))
    ax.axis([min_d1,max_d1,min_d2,max_d2])
    ax.plot([min_d1,max_d1],[0,0],color='silver',linestyle='--')
    ax.plot([0,0],[min_d2,max_d2],color='silver',linestyle='--')

    ax.set_xlabel("Dim."+str(i)+" ("+ str(round(bzc.freq.iloc[(i-1)],2))+")")
    ax.set_ylabel("Dim."+str(i+1)+" ("+ str(round(bzc.freq.iloc[i],2))+")")

    plt.title("Représentation simultanée -" + str(i))
    for i1 in range(df.shape[1]):
        ax.text(acm.col_coord_[i1,(i-1)],acm.col_coord_[i1,i],df.columns[i1],color='dodgerblue')
    
    ### espacer légèrement les individus
    a = -0.08
    for i2 in lrc:
        ax.text(acm.row_coord_[i2,(i-1)],acm.row_coord_[i2,i]+ a,df.index[i2],color='firebrick')        
        a += 0.04
    plt.show()

    print(DActives.iloc[lrc].sort_values(by='periodes').to_markdown())

    i += 2
# Out:
# |      | periodes   | origine_geo   | o1              | o2              | o3              |
# |-----:|:-----------|:--------------|:----------------|:----------------|:----------------|
# | 2273 | 1941-1965  | Europe        | d1_acti_femmes  | d2_enseignement | d3_enseignement |
# |  675 | 1941-1965  | Europe        | d1_acti_femmes  | d2_enseignement | d3_enseignement |
# | 2437 | 1941-1965  | Europe        | d1_acti_femmes  | d2_enseignement | d3_enseignement |
# |  907 | 1941-1965  | Europe        | d1_acti_femmes  | d2_enseignement | d3_enseignement |
# | 2067 | 1941-1965  | Europe        | d1_acti_femmes  | d2_enseignement | d3_enseignement |
# | 2071 | 1941-1965  | Europe        | d1_acti_femmes  | d2_enseignement | d3_enseignement |
# | 2970 | 1941-1965  | Europe        | d1_acti_femmes  | d2_enseignement | d3_enseignement |
# | 1279 | 1941-1965  | Europe        | d1_acti_femmes  | d2_enseignement | d3_enseignement |
# | 2146 | 1966-1990  | Asie          | d1_acti_humains | d2_droit        | d3_droit        |
# | 2662 | 1966-1990  | Asie          | d1_acti_humains | d2_droit        | d3_droit        |
# | 1801 | 1966-1990  | Asie          | d1_acti_humains | d2_droit        | d3_droit        |
# | 1770 | 1966-1990  | Asie          | d1_acti_humains | d2_droit        | d3_droit        |
# | 3092 | 1966-1990  | Asie          | d1_acti_humains | d2_droit        | d3_droit        |
# | 3125 | 1966-1990  | Asie          | d1_acti_humains | d2_droit        | d3_droit        |
# | 2973 | 1966-1990  | Asie          | d1_acti_humains | d2_droit        | d3_droit        |
# | 2814 | 1966-1990  | Asie          | d1_acti_humains | d2_droit        | d3_droit        |
# |      | periodes   | origine_geo      | o1              | o2                         | o3                         |
# |-----:|:-----------|:-----------------|:----------------|:---------------------------|:---------------------------|
# | 2240 | 1941-1965  | Europe           | d1_acti_LGBT    | d2_sciences_experimentales | d3_sciences_experimentales |
# | 2559 | 1941-1965  | Amérique du nord | d1_acti_climat  | d2_sciences_experimentales | d3_sciences_experimentales |
# | 3244 | 1941-1965  | Europe           | d1_acti_LGBT    | d2_sciences_experimentales | d3_sciences_experimentales |
# | 3309 | 1941-1965  | Europe           | d1_acti_humains | d2_sciences_experimentales | d3_sciences_experimentales |
# | 2799 | 1941-1965  | Europe           | d1_acti_LGBT    | d2_sciences_experimentales | d3_sciences_experimentales |
# | 1811 | 1941-1965  | Amérique du nord | d1_acti_climat  | d2_sciences_experimentales | d3_sciences_experimentales |
# |  723 | 1941-1965  | Amérique du nord | d1_acti_climat  | d2_sciences_experimentales | d3_sciences_experimentales |
# | 2834 | 1941-1965  | Europe           | d1_acti_humains | d2_sciences_experimentales | d3_sciences_experimentales |
# |  790 | 1941-1965  | Europe           | d1_acti_humains | d2_sciences_experimentales | d3_sciences_experimentales |
# | 1692 | 1941-1965  | Amérique du nord | d1_acti_climat  | d2_sciences_experimentales | d3_sciences_experimentales |
# | 2495 | 1941-1965  | Amérique du nord | d1_acti_LGBT    | d2_sciences_experimentales | d3_sciences_experimentales |
# | 1922 | 1966-1990  | Europe           | d1_acti_humains | d2_sciences_experimentales | d3_sciences_experimentales |
# | 1447 | 1966-1990  | Europe           | d1_acti_humains | d2_sciences_experimentales | d3_sciences_experimentales |
# | 1675 | 1966-1990  | Europe           | d1_acti_humains | d2_sciences_experimentales | d3_sciences_experimentales |
# | 1778 | 1966-1990  | Europe           | d1_acti_humains | d2_sciences_experimentales | d3_sciences_experimentales |
# | 2362 | 1966-1990  | Europe           | d1_acti_femmes  | d2_sciences_experimentales | d3_sciences_experimentales |
# |      | periodes   | origine_geo      | o1              | o2              | o3              |
# |-----:|:-----------|:-----------------|:----------------|:----------------|:----------------|
# |  393 | 1841-1865  | Europe           | d1_acti_femmes  | d2_droit        | d3_droit        |
# |  185 | 1841-1865  | Europe           | d1_acti_femmes  | d2_droit        | d3_droit        |
# | 1697 | 1866-1890  | Europe           | d1_acti_femmes  | d2_droit        | d3_droit        |
# | 1994 | 1866-1890  | Europe           | d1_acti_femmes  | d2_droit        | d3_droit        |
# |  728 | 1866-1890  | Europe           | d1_acti_femmes  | d2_droit        | d3_droit        |
# | 3006 | 1866-1890  | Europe           | d1_acti_femmes  | d2_droit        | d3_droit        |
# | 2401 | 1941-1965  | Amérique du nord | d1_acti_LGBT    | d2_enseignement | d3_enseignement |
# | 1800 | 1941-1965  | Amérique du nord | d1_acti_LGBT    | d2_enseignement | d3_enseignement |
# |  144 | 1941-1965  | Europe           | d1_acti_femmes  | d2_sante        | d3_sante        |
# | 1105 | 1941-1965  | Europe           | d1_acti_femmes  | d2_sante        | d3_sante        |
# | 1138 | 1941-1965  | Europe           | d1_acti_humains | d2_sante        | d3_sante        |
# | 1777 | 1941-1965  | Europe           | d1_acti_humains | d2_sante        | d3_sante        |
# | 2692 | 1966-1990  | Europe           | d1_acti_femmes  | d2_sante        | d3_sante        |
# | 2993 | 1966-1990  | Europe           | d1_acti_femmes  | d2_sante        | d3_sante        |
# |  693 | 1966-1990  | Europe           | d1_acti_femmes  | d2_sante        | d3_sante        |
# | 2300 | 1966-1990  | Europe           | d1_acti_femmes  | d2_sante        | d3_sante        |
# |      | periodes   | origine_geo     | o1              | o2              | o3              |
# |-----:|:-----------|:----------------|:----------------|:----------------|:----------------|
# | 1794 | 1966-1990  | Asie            | d1_acti_humains | d2_ecrivain_ne  | d3_ecrivain_ne  |
# | 3172 | 1966-1990  | Amérique du sud | d1_acti_LGBT    | d2_enseignement | d3_enseignement |
# | 2981 | 1966-1990  | Asie            | d1_acti_humains | d2_ecrivain_ne  | d3_ecrivain_ne  |
# | 1353 | 1966-1990  | Asie            | d1_acti_humains | d2_ecrivain_ne  | d3_ecrivain_ne  |
# | 1449 | 1966-1990  | Amérique du sud | d1_acti_LGBT    | d2_enseignement | d3_enseignement |
# | 3178 | 1966-1990  | Amérique du sud | d1_acti_LGBT    | d2_enseignement | d3_enseignement |
# | 2955 | 1966-1990  | Amérique du sud | d1_acti_LGBT    | d2_enseignement | d3_enseignement |
# | 3277 | 1966-1990  | Amérique du sud | d1_acti_LGBT    | d2_enseignement | d3_enseignement |
# | 2959 | 1966-1990  | Asie            | d1_acti_humains | d2_ecrivain_ne  | d3_ecrivain_ne  |
# | 2448 | 1966-1990  | Asie            | d1_acti_humains | d2_ecrivain_ne  | d3_ecrivain_ne  |
# | 2512 | 1966-1990  | Amérique du sud | d1_acti_LGBT    | d2_enseignement | d3_enseignement |
# |  913 | 1966-1990  | Amérique du sud | d1_acti_LGBT    | d2_enseignement | d3_enseignement |
# |   21 | 1966-1990  | Asie            | d1_acti_humains | d2_ecrivain_ne  | d3_ecrivain_ne  |
# | 2902 | 1966-1990  | Asie            | d1_acti_humains | d2_ecrivain_ne  | d3_ecrivain_ne  |
# | 1368 | 1966-1990  | Asie            | d1_acti_humains | d2_ecrivain_ne  | d3_ecrivain_ne  |
# | 2331 | 1966-1990  | Amérique du sud | d1_acti_LGBT    | d2_enseignement | d3_enseignement |
