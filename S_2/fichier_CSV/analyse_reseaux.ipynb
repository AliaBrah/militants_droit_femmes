# %% [markdown]
# # Analyse des réseaux
# Essai analyse de réseaux

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import scipy.stats as stats


import pprint
import csv
import sys

import sqlite3 as sql

import time
import datetime
from dateutil import parser

from importlib import reload
from shutil import copyfile


import networkx as nx

from itables import init_notebook_mode, show


from netgraph import Graph, InteractiveGraph

from pyvis.network import Network

from fanalysis.ca import CA 
from fanalysis.mca import MCA
# Importation du fichier csv qui se trouve dans le même dossier que le notebook
data1 = pd.read_csv("analyse_personne_universite.csv")

# %%
len(data1)
# Out:
# 4820

# %%
data1.head(2)
# Out:
#                                 fk_personne                      nom  \
# 0   http://www.wikidata.org/entity/Q6177457     Jeni Bojilova-Pateva
# 1  http://www.wikidata.org/entity/Q16063667  Elisabeth Møller Jensen
#
#    annee_nais                                    fk_uni  \
# 0        1878  http://www.wikidata.org/entity/Q12291455
# 1        1946    http://www.wikidata.org/entity/Q924265
#
#                                        universite
# 0  "Nancho Popovich" Natural Sciences High School
# 1                               Aarhus University

# %%
### Ajouter deux périodes différentes en fonctions de la relation
# Pour la relation 'étudier' créer une période entre 18 et 28 ans (+17, +27) pour l'étendue des études
# Pour la relation 'insitution' ajouté une période d'activité de 19 à 65 ans
data1['YBegin'] = data1[['annee_nais']].apply(lambda x : int(x['annee_nais'] + 17), axis=1)
data1['YEnd'] = data1[['annee_nais']].apply(lambda x : int(x['annee_nais'] + 27), axis=1)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4820 entries, 0 to 4819
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   fk_personne  4820 non-null   object
#  1   nom          4820 non-null   object
#  2   annee_nais   4820 non-null   int64
#  3   fk_uni       4820 non-null   object
#  4   universite   4820 non-null   object
#  5   YBegin       4820 non-null   int64
#  6   YEnd         4820 non-null   int64
# dtypes: int64(3), object(4)
# memory usage: 263.7+ KB

# %%
### Inspecter la distribution des années de naissance
data1.annee_nais.describe()
# Out:
# count    4820.000000
# mean     1949.594191
# std        32.153057
# min      1818.000000
# 25%      1936.000000
# 50%      1954.000000
# 75%      1972.000000
# max      1999.000000
# Name: annee_nais, dtype: float64

# %%
show(data1[[ 'fk_personne','nom','fk_uni','universite','YBegin','YEnd','annee_nais']].sort_values(by='annee_nais'), classes="display", scrollY="200px", 
     scrollCollapse=True, paging=False, column_filters="footer", dom="lrtip")
# Out:
# <table id="itables_1a77dcea_ceb1_47da_b3ff_81871b6bceb6" class="display" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>fk_personne</th>
#       <th>nom</th>
#       <th>fk_uni</th>
#       <th>universite</th>
#       <th>YBegin</th>
#       <th>YEnd</th>
#       <th>annee_nais</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <div style="float:left; margin-right: 10px;">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# </div>
# <div>
# Loading ITables v2.0.1 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </div>
# </tr></tbody>
# <tfoot><th>None</th><th>fk_personne</th><th>nom</th><th>fk_uni</th><th>universite</th><th>YBegin</th><th>YEnd</th><th>annee_nais</th></tfoot>
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.5/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.5/dt_bundle.js';
#
#     document.querySelectorAll("#itables_1a77dcea_ceb1_47da_b3ff_81871b6bceb6:not(.dataTable)").forEach(table => {
#         // Define the table data
#         const data = [[2370, "http://www.wikidata.org/entity/Q452281", "Lucy Stone", "http://www.wikidata.org/entity/Q616591", "Oberlin College", 1835, 1845, 1818], [4693, "http://www.wikidata.org/entity/Q452281", "Lucy Stone", "http://www.wikidata.org/entity/Q8000134", "Wilbraham & Monson Academy", 1835, 1845, 1818], [2106, "http://www.wikidata.org/entity/Q452281", "Lucy Stone", "http://www.wikidata.org/entity/Q1140542", "Mount Holyoke College", 1835, 1845, 1818], [3226, "http://www.wikidata.org/entity/Q313976", "P. G. T. Beauregard", "http://www.wikidata.org/entity/Q9219", "United States Military Academy", 1835, 1845, 1818], [865, "http://www.wikidata.org/entity/Q26763822", "Eunice Newton Foote", "http://www.wikidata.org/entity/Q5372997", "Emma Willard School", 1836, 1846, 1819], [2648, "http://www.wikidata.org/entity/Q26763822", "Eunice Newton Foote", "http://www.wikidata.org/entity/Q49211", "Rensselaer Polytechnic Institute", 1836, 1846, 1819], [3405, "http://www.wikidata.org/entity/Q34787", "Friedrich Engels", "http://www.wikidata.org/entity/Q20266894", "University of Berlin", 1837, 1847, 1820], [1080, "http://www.wikidata.org/entity/Q234572", "Elizabeth Blackwell", "http://www.wikidata.org/entity/Q5533018", "Geneva Medical College", 1838, 1848, 1821], [2978, "http://www.wikidata.org/entity/Q234572", "Elizabeth Blackwell", "http://www.wikidata.org/entity/Q3297997", "State University of New York Upstate Medical University", 1838, 1848, 1821], [258, "http://www.wikidata.org/entity/Q234572", "Elizabeth Blackwell", "http://www.wikidata.org/entity/Q813868", "Bedford College", 1838, 1848, 1821], [2112, "http://www.wikidata.org/entity/Q3189140", "Julie-Victoire Daubi\u00e9", "http://www.wikidata.org/entity/Q838691", "Mus\u00e9um national d'histoire naturelle", 1841, 1851, 1824], [1427, "http://www.wikidata.org/entity/Q60318", "Karl Heinrich Ulrichs", "http://www.wikidata.org/entity/Q152087", "Humboldt University of Berlin", 1842, 1852, 1825], [3780, "http://www.wikidata.org/entity/Q60318", "Karl Heinrich Ulrichs", "http://www.wikidata.org/entity/Q152838", "University of G\u00f6ttingen", 1842, 1852, 1825], [567, "http://www.wikidata.org/entity/Q3119366", "Matilda Joslyn Gage", "http://www.wikidata.org/entity/Q43079959", "Clinton Liberal Institute", 1843, 1853, 1826], [2264, "http://www.wikidata.org/entity/Q24242263", "Harriet Jemima Winifred Clisby", "http://www.wikidata.org/entity/Q4115972", "New York Medical College", 1847, 1857, 1830], [1134, "http://www.wikidata.org/entity/Q2748528", "Emily Davies", "http://www.wikidata.org/entity/Q797846", "Girton College", 1847, 1857, 1830], [1081, "http://www.wikidata.org/entity/Q2418031", "Mary Edwards Walker", "http://www.wikidata.org/entity/Q5533018", "Geneva Medical College", 1849, 1859, 1832], [2104, "http://www.wikidata.org/entity/Q7088941", "Olympia Brown", "http://www.wikidata.org/entity/Q1140542", "Mount Holyoke College", 1852, 1862, 1835], [131, "http://www.wikidata.org/entity/Q7088941", "Olympia Brown", "http://www.wikidata.org/entity/Q4775012", "Antioch College", 1852, 1862, 1835], [133, "http://www.wikidata.org/entity/Q7088941", "Olympia Brown", "http://www.wikidata.org/entity/Q4775035", "Antioch University", 1852, 1862, 1835], [2939, "http://www.wikidata.org/entity/Q7088941", "Olympia Brown", "http://www.wikidata.org/entity/Q1411093", "St. Lawrence University", 1852, 1862, 1835], [3157, "http://www.wikidata.org/entity/Q7088941", "Olympia Brown", "http://www.wikidata.org/entity/Q7782226", "Theological School of St. Lawrence University", 1852, 1862, 1835], [2899, "http://www.wikidata.org/entity/Q191016", "Fredrik Bajer", "http://www.wikidata.org/entity/Q649830", "Sor\u00f8 Academy", 1854, 1864, 1837], [1327, "http://www.wikidata.org/entity/Q98324697", "Emily Josephine Leonard", "http://www.wikidata.org/entity/Q13371", "Harvard University", 1854, 1864, 1837], [3904, "http://www.wikidata.org/entity/Q18086799", "Henry Richard Fox Bou

# %% [markdown]
# # Commentaire
# **il faut peut-être que je nettoye mes données à voir ce que les graphes me donnent**

# %%
organisations = data1.groupby(by='universite').size()
show(organisations.sort_index(ascending=False))
# Out:
# <table id="itables_cb5d44b8_af55_4f42_aec5_8dce5385d1bf" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#     <tr>
#       <th>universite</th>
#       <th></th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <div style="float:left; margin-right: 10px;">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# </div>
# <div>
# Loading ITables v2.0.1 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </div>
# </tr></tbody>
#
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.5/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.5/dt_bundle.js';
#
#     document.querySelectorAll("#itables_cb5d44b8_af55_4f42_aec5_8dce5385d1bf:not(.dataTable)").forEach(table => {
#         // Define the table data
#         const data = [["\u00e9cole normale sup\u00e9rieure", 1], ["\u00c9cole sup\u00e9rieure de commerce de Paris", 1], ["\u00c9cole pratique des hautes \u00e9tudes Section des sciences historiques et philologiques", 1], ["\u00c9cole pratique des hautes \u00e9tudes", 4], ["\u00c9cole normale sup\u00e9rieure de jeunes filles", 1], ["\u00c9cole normale sup\u00e9rieure de Fontenay-aux-Roses", 1], ["\u00c9cole normale sup\u00e9rieure d'Ha\u00efti", 1], ["\u00c9cole normale de Rufisque", 2], ["\u00c9cole nationale sup\u00e9rieure d'arts de Paris-Cergy", 1], ["\u00c9cole nationale d'administration publique", 1], ["\u00c9cole nationale d'administration", 1], ["\u00c9cole du Louvre", 1], ["\u00c9cole des hautes \u00e9tudes internationales et politiques", 2], ["\u00c9cole alsacienne", 1], ["\u00c9cole Normale Sup\u00e9rieure", 4], ["\u00c5hlinska skolan", 1], ["social anthropology", 1], ["secondary school", 1], ["royal atheneum of Mortsel", 1], ["primary school", 1], ["lyc\u00e9e Marie-Curie", 1], ["institute", 1], ["diplomatura", 1], ["commercial school", 1], ["academic degree", 1], ["Zhytomyr Ivan Franko State University", 1], ["Zhejiang University", 1], ["Zagazig University", 1], ["Zaanlands Lyceum", 1], ["Yorktown High School", 1], ["York University", 5], ["York College", 1], ["Yonsei University", 3], ["Yokohama National University", 1], ["Yobe State University", 1], ["Ying Wa Girls' School", 1], ["Yeungnam University", 1], ["Yeshivat Har Etzion", 1], ["Yeshiva University", 3], ["Yerevan State University", 4], ["Yerevan Brusov State University of Languages and Social Sciences", 1], ["Yarmouk University", 1], ["Yanka Kupala State University of Grodno", 3], ["Yale University", 17], ["Yale School of Drama", 1], ["Yale Law School", 12], ["Yale Divinity School", 3], ["Yale College", 3], ["Yadanabon University", 1], ["Xinjiang University", 1], ["Xavier University of Louisiana", 1], ["W\u00f6hlerschule", 1], ["Wycombe High School", 1], ["Wycombe Abbey School", 1], ["Wuhan University", 1], ["Wright State University", 1], ["Worthing High School", 1], ["Worcester College", 1], ["Worcester Academy", 1], ["Woodrow Wilson High School", 1], ["Woodbrooke Quaker Study Centre", 1], ["Women's Human Rights Education Institute", 1], ["Withrow High School", 1], ["Withington Girls' School", 1], ["Winchester College", 1], ["Wilmington University", 1], ["Williams College", 5], ["William Pescod Secondary School", 1], ["Willamette University College of Law", 1], ["Wiley College", 1], ["Wilbraham & Monson Academy", 1], ["Wilberforce University", 1], ["Whetstone High School", 1], ["Wheatley High School", 1], ["Westmont College", 1], ["Westminster Theological Seminary", 2], ["Westminster School", 1], ["Westfield College", 1], ["Western University", 2], ["Western Michigan University Cooley Law School", 1], ["Western Institute of Technology and Higher Education", 1], ["West Virginia Wesleyan College", 1], ["West Virginia State University", 1], ["West Chester Henderson High School", 1], ["Wesleyan University", 6], ["Wesley Girls' High School", 1], ["Wellesley High School", 1], ["Wellesley College", 6], ["Weihenstephan-Triesdorf University of Applied Science", 1], ["Webb City High School", 1], ["Waynflete School", 1], ["Wayne State University", 3], ["Washington University in St.\u00a0Louis", 3], ["Washington State University", 1], ["Washington High School", 1], ["Washington College of Law", 2], ["Waseda University", 2], ["Wasatch Academy", 1], ["Wartburg College", 1], ["Warsaw University of Technology", 1], ["Walnut Grove Secondary School", 1], ["Wallinska skolan", 1], ["Walhampton School", 1], ["Walford Anglican School for Girls", 1], ["Waite High School", 1], ["V\u00e1rosmajori Gimn\u00e1zium", 1], ["Vytautas Magnus University", 1], ["Voronezh State University", 1], ["Volgograd State Pedagogical University", 1], ["Visva-Bharati University", 2], ["Visual Studies", 1], ["Virginia Union University", 1], ["Virginia State University", 1], ["Virginia Military Institu ...

# %%
### Effectif total et les plus représentées
len(organisations), organisations.sort_values(ascending=False).head(10)
# Out:
# (2253,
#  universite
#  Harvard University                                  77
#  Columbia University                                 67
#  University of California, Berkeley                  42
#  London School of Economics and Political Science    39
#  University of Chicago                               28
#  Complutense University of Madrid                    27
#  Harvard Law School                                  26
#  Cornell University                                  23
#  New York University                                 23
#  University of Paris                                 23
#  dtype: int64)

# %%
s = data1.annee_nais

# %%
### Violinplot : densité des naissances dans le temps
#  https://mode.com/blog/violin-plot-examples/
#  https://seaborn.pydata.org/generated/seaborn.violinplot.html#seaborn.violinplot

sns.set_theme(style="whitegrid")

sns.set(rc={"figure.figsize":(14, 7)})

### Personnes nées avant 1931 (protection des données)
# a = s[(s<1931)] 
## Période pré-scientifique
## Décollage de la science 'moderne'
a = s[(s>1800) & (s<2000)] # 
## Science contemporaine
# a = s[(s>1900) ] # 
lim_left=min(a)
lim_right=max(a)





ax = sns.violinplot(x=a)

### Noter que au delà des limites les valeurs sont coupées car postulées
ax.set_xlim(left=lim_left, right=lim_right)
# Out:
# (1818.0, 1999.0)

# %% [markdown]
# ## Période et dictionnaires

# %%
bins=[1801,1850,1900,1950, 2000]

# %%
data1['periode'] = pd.cut(data1['annee_nais'], bins=bins, right=False  )
data1.periode = data1.periode.apply( lambda x : str(x.left) + '_' + str(x.right))

# %%
data1.head(4)
# Out:
#                                 fk_personne                      nom  \
# 0   http://www.wikidata.org/entity/Q6177457     Jeni Bojilova-Pateva
# 1  http://www.wikidata.org/entity/Q16063667  Elisabeth Møller Jensen
# 2  http://www.wikidata.org/entity/Q62081246              Mette Kunøe
# 3  http://www.wikidata.org/entity/Q12326772              Meta Ditzel
#
#    annee_nais                                    fk_uni  \
# 0        1878  http://www.wikidata.org/entity/Q12291455
# 1        1946    http://www.wikidata.org/entity/Q924265
# 2        1937    http://www.wikidata.org/entity/Q924265
# 3        1910    http://www.wikidata.org/entity/Q924265
#
#                                        universite  YBegin  YEnd    periode
# 0  "Nancho Popovich" Natural Sciences High School    1895  1905  1850_1900
# 1                               Aarhus University    1963  1973  1900_1950
# 2                               Aarhus University    1954  1964  1900_1950
# 3                               Aarhus University    1927  1937  1900_1950

# %%
### Effectif par période
data1.groupby(by='periode').size()
# Out:
# /var/folders/8b/5g0mv7wd0xs17dz5xzhfppjm0000gn/T/ipykernel_16128/981809848.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   data1.groupby(by='periode').size()
# periode
# 1801_1850      54
# 1850_1900     351
# 1900_1950    1646
# 1950_2000    2769
# dtype: int64

# %%
ldf = data1[['fk_personne', 'nom','annee_nais', 'fk_uni', 'universite',
       'YBegin', 'YEnd', 'periode']].sort_values(by='nom').to_dict('records')

# %%
ldf[:2]
# Out:
# [{'fk_personne': 'http://www.wikidata.org/entity/Q4648092',
#   'nom': 'A. Latham Staples',
#   'annee_nais': 1977,
#   'fk_uni': 'http://www.wikidata.org/entity/Q812573',
#   'universite': 'Baylor University',
#   'YBegin': 1994,
#   'YEnd': 2004,
#   'periode': '1950_2000'},
#  {'fk_personne': 'http://www.wikidata.org/entity/Q119856937',
#   'nom': 'ABilly S. Jones-Hennin',
#   'annee_nais': 1942,
#   'fk_uni': 'http://www.wikidata.org/entity/Q1068752',
#   'universite': 'Howard University',
#   'YBegin': 1959,
#   'YEnd': 1969,
#   'periode': '1900_1950'}]

# %% [markdown]
# ## Graphe à deux types de sommets
#
# Il s'agit d'un graphe de type 'bipartite'

# %%
l = []
for i in ldf:
    if i['periode'] == '1900_1950':
        l.append(tuple((i['nom'],i['universite'], 
                        {'relationship': i['fk_uni'], "annee_naiss": i['annee_nais'], "periode": i['periode'] })))
l[:5]
# Out:
# [('ABilly S. Jones-Hennin',
#   'Howard University',
#   {'relationship': 'http://www.wikidata.org/entity/Q1068752',
#    'annee_naiss': 1942,
#    'periode': '1900_1950'}),
#  ('ABilly S. Jones-Hennin',
#   'Virginia State University',
#   {'relationship': 'http://www.wikidata.org/entity/Q7934591',
#    'annee_naiss': 1942,
#    'periode': '1900_1950'}),
#  ('Aaron Rhodes',
#   'Reed College',
#   {'relationship': 'http://www.wikidata.org/entity/Q1140775',
#    'annee_naiss': 1949,
#    'periode': '1900_1950'}),
#  ('Aaron Rhodes',
#   'University of Chicago',
#   {'relationship': 'http://www.wikidata.org/entity/Q131252',
#    'annee_naiss': 1949,
#    'periode': '1900_1950'}),
#  ('Abbie Hoffman',
#   'Brandeis University',
#   {'relationship': 'http://www.wikidata.org/entity/Q49119',
#    'annee_naiss': 1936,
#    'periode': '1900_1950'})]

# %%
# Graphe Personne- Organisation
POG=nx.Graph()

# %%
POG.add_edges_from(l)

# %%
### Créer une liste des organisations
l_org = list(organisations.index); len(l_org); l_org[:3]
# Out:
# ['"Nancho Popovich" Natural Sciences High School',
#  'Aarhus University',
#  'Abat Oliba CEU University']

# %%
list(POG.nodes.data())[:4]
# Out:
# [('ABilly S. Jones-Hennin', {}),
#  ('Howard University', {}),
#  ('Virginia State University', {}),
#  ('Aaron Rhodes', {})]

# %%
### Ajouter au sommets un code si personne ou organisation
# On utiliser pour ce faire la liste des organisations
types = {}
for e in list(POG.nodes):
    if e in l_org:
        t = 'O'
    else:
        t = 'P'
    types[e] = {'type': t} 
[(k,v )for k,v in types.items()][:3]
# Out:
# [('ABilly S. Jones-Hennin', {'type': 'P'}),
#  ('Howard University', {'type': 'O'}),
#  ('Virginia State University', {'type': 'O'})]

# %%
nx.set_node_attributes(POG, types)
list(POG.nodes.data())[:3]
# Out:
# [('ABilly S. Jones-Hennin', {'type': 'P'}),
#  ('Howard University', {'type': 'O'}),
#  ('Virginia State University', {'type': 'O'})]

# %%
### Ajouter la centralité de degré
# grâce à un dictionnaire construit selon le format souhaité
degree = dict([(d[0], {'degree': d[1]}) for d in nx.degree(POG)])

# %%
nx.set_node_attributes(POG, degree)

# %%
print(list(POG.nodes.data())[:4])
# Out:
# [('ABilly S. Jones-Hennin', {'type': 'P', 'degree': 2}), ('Howard University', {'type': 'O', 'degree': 9}), ('Virginia State University', {'type': 'O', 'degree': 1}), ('Aaron Rhodes', {'type': 'P', 'degree': 2})]

# %%
persons_degree = []
for n in list(POG.nodes.data()):
    if n[1]['type'] == 'P':
        persons_degree.append([n[0], n[1]['degree']])

# %%
sorted(persons_degree, key = lambda x : x[1], reverse=True)[:10]
# Out:
# [['Pauli Murray', 8],
#  ['Martin Luther King Jr.', 7],
#  ['Susan Sontag', 7],
#  ['Anne Gayle Ingram', 6],
#  ['Aung San Suu Kyi', 6],
#  ['Aisha Al-Mana', 5],
#  ['Al Gore', 5],
#  ['Audre Lorde', 5],
#  ['Corliss Lamont', 5],
#  ['Desmond Tutu', 5]]

# %%
org_degree = []
for n in list(POG.nodes.data()):
    if n[1]['type'] == 'O':
        org_degree.append([n[0], n[1]['degree']])

# %%
sorted(org_degree, key = lambda x : x[1], reverse=True)[:10]
# Out:
# [['Harvard University', 34],
#  ['Columbia University', 34],
#  ['University of Chicago', 17],
#  ['University of California, Berkeley', 17],
#  ['London School of Economics and Political Science', 15],
#  ['Cornell University', 12],
#  ['University of Sydney', 11],
#  ['Stanford University', 11],
#  ['University of Chile', 11],
#  ['University of Amsterdam', 11]]

# %%
edges = list(POG.edges.data())
edges[:5]
# Out:
# [('ABilly S. Jones-Hennin',
#   'Howard University',
#   {'relationship': 'http://www.wikidata.org/entity/Q1068752',
#    'annee_naiss': 1942,
#    'periode': '1900_1950'}),
#  ('ABilly S. Jones-Hennin',
#   'Virginia State University',
#   {'relationship': 'http://www.wikidata.org/entity/Q7934591',
#    'annee_naiss': 1942,
#    'periode': '1900_1950'}),
#  ('Howard University',
#   'Andrew Young',
#   {'relationship': 'http://www.wikidata.org/entity/Q1068752',
#    'annee_naiss': 1932,
#    'periode': '1900_1950'}),
#  ('Howard University',
#   'Diane Nash',
#   {'relationship': 'http://www.wikidata.org/entity/Q1068752',
#    'annee_naiss': 1938,
#    'periode': '1900_1950'}),
#  ('Howard University',
#   'Kanitha Wichiencharoen',
#   {'relationship': 'http://www.wikidata.org/entity/Q1068752',
#    'annee_naiss': 1920,
#    'periode': '1900_1950'})]

# %%
labels = {}    
for node in POG.nodes():
    labels[node] = node

# %%
nx.set_node_attributes(POG, labels, 'label')

# %%
nodes = list(POG.nodes.data())
nodes[:5]
# Out:
# [('ABilly S. Jones-Hennin',
#   {'type': 'P', 'degree': 2, 'label': 'ABilly S. Jones-Hennin'}),
#  ('Howard University',
#   {'type': 'O', 'degree': 9, 'label': 'Howard University'}),
#  ('Virginia State University',
#   {'type': 'O', 'degree': 1, 'label': 'Virginia State University'}),
#  ('Aaron Rhodes', {'type': 'P', 'degree': 2, 'label': 'Aaron Rhodes'}),
#  ('Reed College', {'type': 'O', 'degree': 1, 'label': 'Reed College'})]

# %% [markdown]
# ### Analyse du Graphe

# %%
components = nx.connected_components(POG);
components_l = [len(c) for c in sorted(nx.connected_components(POG), key=len, reverse=True)]
len(components_l), components_l[:5]
# Out:
# (355, [846, 29, 25, 11, 11])

# %%
S = [POG.subgraph(c).copy() for c in nx.connected_components(POG)]

# %%
ln = sorted([[i,len(s.nodes)] for i,s in enumerate(S)], key = lambda row: row[1], reverse=True); ln[:8]
# Out:
# [[0, 846], [34, 29], [20, 25], [18, 11], [68, 11], [53, 10], [84, 10], [10, 9]]

# %%
li=[n[0] for n in ln]

# %%
S[21].nodes
# Out:
# NodeView(('University of Bucharest', 'Cezar Mititelu', 'Mihai Botez', 'Alexandru Ioan Cuza University', 'Alexandru Monciu-Sudinski'))

# %% [markdown]
# ### Représenter le graphe

# %%
u = S[14]

# %%
u = nx.Graph()
for i in li[:5]:
    u = nx.union(u, S[i])
type(u)
# Out:
# networkx.classes.graph.Graph

# %%
plt.figure(figsize = (30,30))

#g = POG
g = u

#pos = nx.kamada_kawai_layout(g)
pos = nx.spring_layout(g)

no = [x for x,y in g.nodes(data=True) if y['type']=='O']
np = [x for x,y in g.nodes(data=True) if y['type']=='P'] 

co = 'fuchsia'
cp = 'grey'
nx.draw_networkx_nodes(g, pos, nodelist=np, node_color=cp, alpha=0.6)
nx.draw_networkx_nodes(g, pos, nodelist=no, node_color=co, alpha=0.8)
nx.draw_networkx_edges(g, pos, alpha=0.6) # edgelist=ln, edge_color=c, 
nx.draw_networkx_labels(g, pos, alpha=0.7, font_size=9)


plt.show()

# %% [markdown]
# **Graphe pour 1900_1950** il est beaucoup plus fourni que celui de la seconde moitié du 19ème

# %% [markdown]
# ## Création de relation entre les personnes
# * Tester le lien entre l'université et période

# %%
### Pairs de personnes
pairs_p = []

for s1 in ldf:
    for s2 in ldf:
        if s1['nom'] < s2['nom'] \
            and s1['universite'] == s2['universite'] \
            and s2['YEnd'] > s1['YBegin'] \
            and s2['YBegin'] < s1['YEnd']:
            pairs_p.append([s1,s2])
        else:
            pass

# %%
len(pairs_p)
# Out:
# 3934

# %%
pairs_p[:2]
# Out:
# [[{'fk_personne': 'http://www.wikidata.org/entity/Q119856937',
#    'nom': 'ABilly S. Jones-Hennin',
#    'annee_nais': 1942,
#    'fk_uni': 'http://www.wikidata.org/entity/Q1068752',
#    'universite': 'Howard University',
#    'YBegin': 1959,
#    'YEnd': 1969,
#    'periode': '1900_1950'},
#   {'fk_personne': 'http://www.wikidata.org/entity/Q5271535',
#    'nom': 'Diane Nash',
#    'annee_nais': 1938,
#    'fk_uni': 'http://www.wikidata.org/entity/Q1068752',
#    'universite': 'Howard University',
#    'YBegin': 1955,
#    'YEnd': 1965,
#    'periode': '1900_1950'}],
#  [{'fk_personne': 'http://www.wikidata.org/entity/Q119856937',
#    'nom': 'ABilly S. Jones-Hennin',
#    'annee_nais': 1942,
#    'fk_uni': 'http://www.wikidata.org/entity/Q1068752',
#    'universite': 'Howard University',
#    'YBegin': 1959,
#    'YEnd': 1969,
#    'periode': '1900_1950'},
#   {'fk_personne': 'http://www.wikidata.org/entity/Q509860',
#    'nom': 'Stokely Carmichael',
#    'annee_nais': 1941,
#    'fk_uni': 'http://www.wikidata.org/entity/Q1068752',
#    'universite': 'Howard University',
#    'YBegin': 1958,
#    'YEnd': 1968,
#    'periode': '1900_1950'}]]

# %% [markdown]
# ## Pairs d'organisation

# %%
## Pairs d'organisations
pairs_o = []

for s1 in ldf:
    for s2 in ldf:
        if s1['universite'] < s2['universite'] \
            and s1['nom'] == s2['nom']:
                pairs_o.append([s1,s2])
        else:
            pass

# %%
len(pairs_o)
# Out:
# 2876

# %%
### Apparaissent des parcours de vie
pairs_o[:2]
# Out:
# [[{'fk_personne': 'http://www.wikidata.org/entity/Q119856937',
#    'nom': 'ABilly S. Jones-Hennin',
#    'annee_nais': 1942,
#    'fk_uni': 'http://www.wikidata.org/entity/Q1068752',
#    'universite': 'Howard University',
#    'YBegin': 1959,
#    'YEnd': 1969,
#    'periode': '1900_1950'},
#   {'fk_personne': 'http://www.wikidata.org/entity/Q119856937',
#    'nom': 'ABilly S. Jones-Hennin',
#    'annee_nais': 1942,
#    'fk_uni': 'http://www.wikidata.org/entity/Q7934591',
#    'universite': 'Virginia State University',
#    'YBegin': 1959,
#    'YEnd': 1969,
#    'periode': '1900_1950'}],
#  [{'fk_personne': 'http://www.wikidata.org/entity/Q4662358',
#    'nom': 'Aaron Rhodes',
#    'annee_nais': 1949,
#    'fk_uni': 'http://www.wikidata.org/entity/Q1140775',
#    'universite': 'Reed College',
#    'YBegin': 1966,
#    'YEnd': 1976,
#    'periode': '1900_1950'},
#   {'fk_personne': 'http://www.wikidata.org/entity/Q4662358',
#    'nom': 'Aaron Rhodes',
#    'annee_nais': 1949,
#    'fk_uni': 'http://www.wikidata.org/entity/Q131252',
#    'universite': 'University of Chicago',
#    'YBegin': 1966,
#    'YEnd': 1976,
#    'periode': '1900_1950'}]]

# %% [markdown]
# ## Personnes (filtres, sous populations)
# on va commencer par la période que le graphe d'avant 1850-1900

# %%
prem_20_pairs = [p for p in pairs_p if ((p[0]['periode']=='1850_1900') & (p[1]['periode']=='1850_1900'))]

# %%
len(prem_20_pairs), prem_20_pairs[:3]
# Out:
# (109,
#  [[{'fk_personne': 'http://www.wikidata.org/entity/Q96052486',
#     'nom': 'Agnes Metcalfe',
#     'annee_nais': 1870,
#     'fk_uni': 'http://www.wikidata.org/entity/Q170027',
#     'universite': 'University of London',
#     'YBegin': 1887,
#     'YEnd': 1897,
#     'periode': '1850_1900'},
#    {'fk_personne': 'http://www.wikidata.org/entity/Q254858',
#     'nom': 'Emily Davison',
#     'annee_nais': 1872,
#     'fk_uni': 'http://www.wikidata.org/entity/Q170027',
#     'universite': 'University of London',
#     'YBegin': 1889,
#     'YEnd': 1899,
#     'periode': '1850_1900'}],
#   [{'fk_personne': 'http://www.wikidata.org/entity/Q179558',
#     'nom': 'Alexandra Kollontai',
#     'annee_nais': 1872,
#     'fk_uni': 'http://www.wikidata.org/entity/Q206702',
#     'universite': 'University of Zurich',
#     'YBegin': 1889,
#     'YEnd': 1899,
#     'periode': '1850_1900'},
#    {'fk_personne': 'http://www.wikidata.org/entity/Q60568721',
#     'nom': 'Eva Haljecka Petković',
#     'annee_nais': 1870,
#     'fk_uni': 'http://www.wikidata.org/entity/Q206702',
#     'universite': 'University of Zurich',
#     'YBegin': 1887,
#     'YEnd': 1897,
#     'periode': '1850_1900'}],
#   [{'fk_personne': 'http://www.wikidata.org/entity/Q179558',
#     'nom': 'Alexandra Kollontai',
#     'annee_nais': 1872,
#     'fk_uni': 'http://www.wikidata.org/entity/Q206702',
#     'universite': 'University of Zurich',
#     'YBegin': 1889,
#     'YEnd': 1899,
#     'periode': '1850_1900'},
#    {'fk_personne': 'http://www.wikidata.org/entity/Q121500',
#     'nom': 'Johanna Elberskirchen',
#     'annee_nais': 1864,
#     'fk_uni': 'http://www.wikidata.org/entity/Q206702',
#     'universite': 'University of Zurich',
#     'YBegin': 1881,
#     'YEnd': 1891,
#     'periode': '1850_1900'}]])

# %% [markdown]
# Filtrer les universités mais pas les même données que l'exemple --> ? comment faire ? peut-être pas besoin faire que les personnes.

# %% [markdown]
# ## Exploration graphe personnes

# %%
l = []
for i in prem_20_pairs: #almaMater_pairs:
    l.append(tuple((i[0]['nom'],i[1]['nom'], {'relationship': f"{i[0]['universite']}_{i[1]['universite']}", 
                                                              'organisation': i[0]['universite'] })))
l[:5]
# Out:
# [('Agnes Metcalfe',
#   'Emily Davison',
#   {'relationship': 'University of London_University of London',
#    'organisation': 'University of London'}),
#  ('Alexandra Kollontai',
#   'Eva Haljecka Petković',
#   {'relationship': 'University of Zurich_University of Zurich',
#    'organisation': 'University of Zurich'}),
#  ('Alexandra Kollontai',
#   'Johanna Elberskirchen',
#   {'relationship': 'University of Zurich_University of Zurich',
#    'organisation': 'University of Zurich'}),
#  ('Alexandra Kollontai',
#   'Selma von Lengefeld',
#   {'relationship': 'University of Zurich_University of Zurich',
#    'organisation': 'University of Zurich'}),
#  ('Alexandra Kollontai',
#   'Sofia Okunevska',
#   {'relationship': 'University of Zurich_University of Zurich',
#    'organisation': 'University of Zurich'})]

# %%
EMP=nx.Graph()
EMP.add_edges_from(l)
nodes = list(EMP.nodes.data())
nodes[:5]
# Out:
# [('Agnes Metcalfe', {}),
#  ('Emily Davison', {}),
#  ('Alexandra Kollontai', {}),
#  ('Eva Haljecka Petković', {}),
#  ('Johanna Elberskirchen', {})]

# %%
edges = list(EMP.edges.data())
edges[:5]
# Out:
# [('Agnes Metcalfe',
#   'Emily Davison',
#   {'relationship': 'University of London_University of London',
#    'organisation': 'University of London'}),
#  ('Emily Davison',
#   'Eleanor Rathbone',
#   {'relationship': 'Kensington Prep School_Kensington Prep School',
#    'organisation': 'Kensington Prep School'}),
#  ('Alexandra Kollontai',
#   'Eva Haljecka Petković',
#   {'relationship': 'University of Zurich_University of Zurich',
#    'organisation': 'University of Zurich'}),
#  ('Alexandra Kollontai',
#   'Johanna Elberskirchen',
#   {'relationship': 'University of Zurich_University of Zurich',
#    'organisation': 'University of Zurich'}),
#  ('Alexandra Kollontai',
#   'Selma von Lengefeld',
#   {'relationship': 'University of Zurich_University of Zurich',
#    'organisation': 'University of Zurich'})]

# %%
labels = {}    
for node in EMP.nodes():
    labels[node] = node

# %% [markdown]
# ## Analyser les composantes du graphe

# %%
components = nx.connected_components(EMP);
components_l = [len(c) for c in sorted(nx.connected_components(EMP), key=len, reverse=True)]
len(components_l), components_l[:5]
# Out:
# (25, [9, 8, 8, 7, 5])

# %%
S = [EMP.subgraph(c).copy() for c in nx.connected_components(EMP)]

# %%
ln = sorted([[i,len(s.nodes)] for i,s in enumerate(S)], key = lambda row: row[1], reverse=True); ln[:8]
# Out:
# [[4, 9], [1, 8], [10, 8], [5, 7], [2, 5], [3, 5], [9, 4], [11, 4]]

# %%
li=[n[0] for n in ln]

# %%
## type de graphe
u = nx.Graph()
for i in li[1:3]:
    u = nx.union(u, S[i])
type(u)
# Out:
# networkx.classes.graph.Graph

# %%
u = S[5]

# %%
plt.figure(figsize = (30,30))

#g = POG
g = u

#pos = nx.kamada_kawai_layout(g)
### https://networkx.org/documentation/stable/reference/generated/networkx.drawing.layout.spring_layout.html
pos = nx.spring_layout(g, k=1)

labels = {e: u.get_edge_data(e[0], e[1])["organisation"] for e in u.edges()}

cp = 'grey'
nx.draw_networkx_nodes(g, pos, node_color=cp, alpha=0.8)
nx.draw_networkx_edges(g, pos, alpha=0.6) # edgelist=ln, edge_color=c, 
nx.draw_networkx_labels(g, pos, alpha=0.7, font_size=11)
nx.draw_networkx_edge_labels(g, pos=pos, edge_labels=labels)



plt.show()

# %% [markdown]
# **ça fonctionne pas pour le 20ème siècle mais pour 1850-1900 oui**

# %% [markdown]
# ## organisation relations entre université je ne sais pas comment le faire ?
